# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# requests.get('https://www.ambitionbox.com/list-of-companies?page=1')
# requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text   will say that we do not have permission to access

# %%
#TO CORRECT THE ABOVE CODE:
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers)

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
# To extracts all the h1s from the website
soup.find_all('h1')

# %% [markdown]
# <h2 style="color:#DE006F">IMPORT LIBRARIES</h2>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('customer.csv')

# %% [markdown]
# <H2 style="color:#DE006F">DATA ANALYSIS AND PROCESSING</H2>

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 40   39    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# 27   69  Female     Poor        PG        No
# 0    30  Female  Average    School        No
# 24   16  Female  Average        PG       Yes

# %%
df=df.iloc[:,2:]

# %%
df.head(3)
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No

# %% [markdown]
# <H2 style="color:#DE006F">TRAIN AND TEST SPLIT</H2>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
X_train
# Out:
#      review education
# 31     Poor    School
# 9      Good        UG
# 23     Good    School
# 29  Average        UG
# 38     Good    School
# 49     Good        UG
# 42     Good        PG
# 33     Good        PG
# 13  Average    School
# 4   Average        UG
# 35     Poor    School
# 43     Poor        PG
# 21  Average        PG
# 19     Poor        PG
# 44  Average        UG
# 48     Good        UG
# 14     Poor        PG
# 22     Poor        PG
# 16     Poor        UG
# 5   Average    School
# 26     Poor        PG
# 40     Good    School
# 11     Good        UG
# 46     Poor        PG
# 47     Good        PG
# 1      Poor        UG
# 24  Average        PG
# 18     Good    School
# 20  Average    School
# 12     Poor    School
# 2      Good        PG
# 39     Poor        PG
# 28     Poor    School
# 8   Average        UG
# 27     Poor        PG
# 45     Poor        PG
# 36     Good        UG
# 32  Average        UG
# 25     Good    School
# 10     Good        UG

# %% [markdown]
# <H2 style="color:#DE006F">APPLYING ORDINAL ENCODING TO ORDINAL FEATURES</H2>

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
X_train_encoded=oe.transform(X_train)
X_test_encoded=oe.transform(X_test)

# %%
X_train_encoded
# Out:
# array([[0., 0.],
#        [2., 1.],
#        [2., 0.],
#        [1., 1.],
#        [2., 0.],
#        [2., 1.],
#        [2., 2.],
#        [2., 2.],
#        [1., 0.],
#        [1., 1.],
#        [0., 0.],
#        [0., 2.],
#        [1., 2.],
#        [0., 2.],
#        [1., 1.],
#        [2., 1.],
#        [0., 2.],
#        [0., 2.],
#        [0., 1.],
#        [1., 0.],
#        [0., 2.],
#        [2., 0.],
#        [2., 1.],
#        [0., 2.],
#        [2., 2.],
#        [0., 1.],
#        [1., 2.],
#        [2., 0.],
#        [1., 0.],
#        [0., 0.],
#        [2., 2.],
#        [0., 2.],
#        [0., 0.],
#        [1., 1.],
#        [0., 2.],
#        [0., 2.],
#        [2., 1.],
#        [1., 1.],
#        [2., 0.],
#        [2., 1.]])

# %% [markdown]
# <h2 style="color:#DE006F">TO CHECK THE CATEGORIES</h2>

# %%
oe.categories_
# Out:
# [array(['Poor', 'Average', 'Good'], dtype=object),
#  array(['School', 'UG', 'PG'], dtype=object)]
